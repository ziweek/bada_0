# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type('10')
# Out:
# str

# %%
list_name = ['김지욱', '김종현']

# %%
list_name.append('조수현')
list_name
# Out:
# ['김지욱', '김종현', '조수현']

# %%
list_name.extend(['이지원'])
list_name
# Out:
# ['김지욱', '김종현', '조수현', '이지원']

# %%
list_name.pop(0)
list_name
# Out:
# ['조수현']

# %% [markdown]
# User > name, money, stock
# Stock > name, price, change
#
# -> class

# %%
class User:
    def __init__(self, name, money, stock):
        self.name = name
        self.money = money
        self.stock = stock
        
    def info(self):
        print(f'name is {self.name}')
        print(f'money is {self.money}')
        print(f'stock is {self.stock}')

# %%
class Stock:
    def __init__(self, name, price, change):
        self.name = name
        self.price = price
        self.change = change
        
    def info(self):
        print(f'name is {self.name}')
        print(f'price is {self.price}')
        print(f'change is {self.change}')

# %%
user_name = input('이름을 입력하시오 : ')
user_money = int(input('투자금을 입력하시오 : '))
# Out:
# 이름을 입력하시오 :  김지욱
# 투자금을 입력하시오 :  1000

# %%
kim = User(user_name, user_money, 0)

# %%
wapple = Stock('wapple', 1000, 0)

# %%
while True:
    inp = input('? : ')
    if inp == '종료':
        print('게임이 종료되었습니다.')
        break
    elif inp == '매입':
        print('매입하였습니다.')
    elif inp == '매도':
        print('매도하였습니다.')
    else:
        print('잘못된 명령입니다.')
# Out:
# ? :  매입
# 매입하였습니다.
# ? :  매도
# 매도하였습니다.
# ? :  배고파
# 잘못된 명령입니다.
# ? :  종료
# 게임이 종료되었습니다.

# %% [markdown]
# # 크롤링

# %%
import urllib.request as req
from bs4 import BeautifulSoup

url = 'https://namu.wiki/w/%EC%A1%B0%EC%9C%A0%EB%A6%AC'


###
header = {'User-Agent' : 'Mozilla/5.0'}
respose = req.Request(url, headers=header)
###


html = req.urlopen(respose)
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.find_all(class_='_2RBnxNOu', attrs={'alt':'조유리 Op.22 프로필', 'data-filesize':'47162'})[0]['data-src']
# Out:
# '//w.namu.la/s/73ec6934e89b0543f5fa07f1cd894de5ba43c4e1ba2010047d4c566a6b94f10723d30f1ed441f6afdac46d408bd03a7d59260e3ec9347af0cef601f120a9e482c77600aad252a8bd71b76551364989c5db9b644d40ce86875c66a5b73863ace2d6dab2701146eebf128b6499b30b61cd'

# %%
soup.find_all(class_='_2RBnxNOu', attrs={'alt':'조유리 Op.22 프로필', 'data-filesize':'47162'})[0]['data-src']
# Out:
# '//w.namu.la/s/73ec6934e89b0543f5fa07f1cd894de5ba43c4e1ba2010047d4c566a6b94f10723d30f1ed441f6afdac46d408bd03a7d59260e3ec9347af0cef601f120a9e482c77600aad252a8bd71b76551364989c5db9b644d40ce86875c66a5b73863ace2d6dab2701146eebf128b6499b30b61cd'

# %%
table = soup.find_all(class_='Vny1Dcs5')[0]

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
import pandas as pd


df = pd.read_html(str(table))
df_new = df[0]

# %%
df_new2 = df_new.drop(3, axis=1)
df_new3 = df_new2.drop(0, axis=0)
df_new3.columns = ['가을 상자', 'GLASSY', '무곡집']
df_new3
# Out:
#                     가을 상자                  GLASSY  \
# 1  가을 상자디지털 싱글2021.09.23.  GLASSY싱글 1집2021.10.07.
# 2  가을 상자디지털 싱글2021.09.23.  GLASSY싱글 1집2021.10.07.
#
#                                           무곡집
# 1                                조유리 2022 무곡집
# 2  Op.22 Y-Waltz : in Major미니 1집2022. 06. 02.

# %%
soup.
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# /var/folders/hz/hxmpndyx46ncqhsm2yc43k8r0000gn/T/ipykernel_15475/1986944723.py in <module>
# ----> 1 soup.select('#iVc83Qsld > div.\30 92976b9 > div > div > div > div > div > div > div.t9Qh3kCS > div:nth-child(8) > div > div > div > div > div:nth-child(3) > div > div > div > div > div > div > div > div:nth-child(14) > div > div > div > div:nth-child(1) > div > div:nth-child(58) > div > div > div > table')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py in select(self, selector, namespaces, limit, **kwargs)
#    1947             )
#    1948
# -> 1949         results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1950
#    1951         # We do this because it's more consistent and because
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#      96     """Select the specified tags."""
#      97
# ---> 98     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#      99
#     100
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/__init__.py in compile(pattern, namespaces, flags, **kwargs)
#      60         return pattern
#      61
# ---> 62     return cp._cached_css_compile(pattern, namespaces, custom, flags)
#      63
#      64
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/css_parser.py in _cached_css_compile(pattern, namespaces, custom, flags)
#     209     return cm.SoupSieve(
#     210         pattern,
# --> 211         CSSParser(pattern, custom=custom_selectors, flags=flags).process_selectors(),
#     212         namespaces,
#     213         custom,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/css_parser.py in process_selectors(self, index, flags)
#    1056         """Process selectors."""
#    1057
# -> 1058         return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#    1059
#    1060
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/css_parser.py in parse_selectors(self, iselector, index, flags)
#     907         try:
#     908             while True:
# --> 909                 key, m = next(iselector)
#     910
#     911                 # Handle parts
#
# ~/opt/anaconda3/lib/python3.9/site-packages/soupsieve/css_parser.py in selector_iter(self, pattern)
#    1049                 else:
#    1050                     msg = "Invalid character {!r} position {}".format(c, index)
# -> 1051                 raise SelectorSyntaxError(msg, self.pattern, index)
#    1052         if self.debug:  # pragma: no cover
#    1053             print('## END PARSING')
#
# SelectorSyntaxError: Malformed class selector at position 16
#   line 1:
# #iVc83Qsld > div. 92976b9 > div > div > div > div > div > div > div.t9Qh3kCS > div:nth-child(8) > div > div > div > div > div:nth-child(3) > div > div > div > div > div > div > div > div:nth-child(14) > div > div > div > div:nth-child(1) > div > div:nth-child(58) > div > div > div > table
#                 ^

# %% [markdown]
# # Pandas

# %%
import pandas as pd

df = pd.read_csv('info.csv', engine='python', encoding='euc-kr')
df
# Out:
#     연번 차지구명   행정동                         서울특별시 용산구 설치장소    그늘막구분 그늘막지름
# 0    1  용산구   후암동          서울특별시 용산구 후암로 47 파리바게트 앞 횡단보도  접이식 고정형    5m
# 1    2  용산구   후암동                서울특별시 용산구 후암로 51 앞 횡단보도  접이식 고정형    5m
# 2    3  용산구   후암동       서울특별시 용산구 소월로 109 남산도서관 맞은편 횡단보도  접이식 고정형    5m
# 3    4  용산구   후암동              서울특별시 용산구 신흥로 152 건너편 교통섬  접이식 고정형    5m
# 4    5  용산구   남영동          서울특별시 용산구 한강대로77길 4-1 앞 횡단보도   접이식 고정형    5m
# ..  ..  ...   ...                                    ...      ...   ...
# 90  91  용산구  서빙고동     서울특별시 용산구 효창공원(효창원로 177-18) 내 매점 앞  접이식 고정형    5m
# 91  92  용산구  서빙고동           서울특별시 용산구 신계역사공원(청파로 139-25)  접이식 고정형    5m
# 92  93  용산구  서빙고동           서울특별시 용산구 신계역사공원(청파로 139-25)  접이식 고정형    5m
# 93  94  용산구  서빙고동  서울특별시 용산구 응봉근린공원(한남동 726-181) 관리사무소 옆  접이식 고정형    5m
# 94  95  용산구  서빙고동         서울특별시 용산구 청파선린공원(청파동3가 118-56)  접이식 고정형    5m
#
# [95 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   연번              95 non-null     int64
#  1   차지구명            95 non-null     object
#  2   행정동             95 non-null     object
#  3   서울특별시 용산구 설치장소  95 non-null     object
#  4   그늘막구분           95 non-null     object
#  5   그늘막지름           95 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 4.6+ KB

# %%
df.describe()
# Out:
#               연번
# count  95.000000
# mean   48.000000
# std    27.568098
# min     1.000000
# 25%    24.500000
# 50%    48.000000
# 75%    71.500000
# max    95.000000

# %%
df.value_counts()
# Out:
# 연번  차지구명  행정동    서울특별시 용산구 설치장소                          그늘막구분    그늘막지름
# 1   용산구   후암동    서울특별시 용산구 후암로 47 파리바게트 앞 횡단보도           접이식 고정형  5m       1
# 61  용산구   이태원1동  서울특별시 용산구 이태원역 2번출구 옆                   접이식 고정형  5m       1
# 70  용산구   한남동    서울특별시 용산구 이태원로 221 앞 횡단보도               스마트      5.4m     1
# 69  용산구   한남동    서울특별시 용산구 이태원로 222 제일기획 앞 횡단보도          접이식 고정형  5m       1
# 68  용산구   이태원2동  서울특별시 용산구 회나무로13가길 64 옆 소공원             접이식 고정형  5m       1
#                                                                           ..
# 30  용산구   용문동    서울특별시 용산구 효창공원앞역 4번출구 입구 버스정류장(03-180)  접이식 고정형  5m       1
# 29  용산구   용문동    서울특별시 용산구 효창공원앞역 5번출구 앞 횡단보도            접이식 고정형  5m       1
# 28  용산구   용문동    서울특별시 용산구 효창공원앞역 6번출구 뒤                 접이식 고정형  5m       1
# 27  용산구   용문동    서울특별시 용산구 효창공원앞역 3번출구 뒤 횡단보도            접이식 고정형  5m       1
# 95  용산구   서빙고동   서울특별시 용산구 청파선린공원(청파동3가 118-56)          접이식 고정형  5m       1
# Length: 95, dtype: int64

# %%
df.groupby('행정동').count()['서울특별시 용산구 설치장소'].describe()
# Out:
# count    14.000000
# mean      6.785714
# std       6.116542
# min       2.000000
# 25%       3.250000
# 50%       4.000000
# 75%       7.000000
# max      23.000000
# Name: 서울특별시 용산구 설치장소, dtype: float64

# %% [markdown]
# # Numpy
